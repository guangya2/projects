# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.metrics import pairwise_distances,euclidean_distances
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import pandas as pd
from scipy.spatial.distance import pdist,squareform,euclidean
from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train.reshape(50000,3072)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 29s 0us/step

# %%
X_train = X_train.reshape(50000,3072)
X_test = X_test.reshape(10000,3072)

# %%
data_set = np.vstack((X_train,X_test))
label_set = np.vstack((y_train,y_test))

# %%
df = pd.DataFrame(np.hstack((data_set,label_set)),columns = [(i for i in range(3072))].append(3072))

# %%
mean_images = df.groupby(3072).mean().values

# %%
data_dict = {}
for i in range(10):
    key = "data" + str(i)
    data_dict[key] = df[df[3072] == i].drop(columns = [3072]).values

# %%
pca_dict = {}
project_dict = {}
error_dict = {}
for key, value in data_dict.items():
    model = PCA(20).fit(value)
    pca_dict[key] = model.components_
    project_dict[key] = model.inverse_transform(model.transform(value))
    error_dict[key] = (euclidean(project_dict[key].flatten(),value.flatten())**2) / len(value)

# %%
plt.rcParams["axes.grid"] = False
plt.figure(figsize=(15,12))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(mean_images[i].reshape((32,32,3)) / (255.0))
plt.savefig('mean.png')
plt.show()
plt.close()

# %%
class_name = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck',
}
df_error = pd.DataFrame(list(error_dict.values()),index = class_name.values())

# %%
plt.figure()
df_error.plot.bar(color = 'gbrwy')
plt.xlabel("Category")
plt.ylabel("mean error")
plt.title("bar plot for PCA error of each category")
plt.legend().remove()
plt.savefig('error.png')
plt.show()
plt.close()

# %%
D = pairwise_distances(mean_images)
D = D ** 2

# %%
np.savetxt("partb_distances.csv", D, delimiter=",")

# %%
A = np.identity(10) - (np.ones(10).reshape((10,1)) @ (np.ones(10).reshape(1,10)))/10
W = (A@D@A.T) / -2
s,v = np.linalg.eig(W)
result = v[:,:2] @ np.diag(s[:2] ** 0.5)
plt.figure()
plt.scatter(result[:, 0], result[:, 1])
plt.axis('equal');
plt.xlabel("First component")
plt.ylabel("Second component")
plt.title("plot for PCoA dimension reduction")
plt.savefig("PartB.png")
plt.show()
plt.close()

# %%
def calculate_difference(a,b):
    return (euclidean(a.flatten(),b.flatten()) ** 2 / len(a))
error_diff_array = []
for i in range(10):
    keyi = "data" + str(i)
    for j in range(10):
        keyj = "data" + str(j)
        a = data_dict[keyi]
        value = data_dict[keyj]
        modeli = PCA(20).fit(value)
        modelj = PCA(20).fit(a)
        modeli.mean_ = mean_images[i]
        modelj.mean_ = mean_images[j]
        projecti = modeli.inverse_transform(modeli.transform(a))
        projectj = modelj.inverse_transform(modelj.transform(value))
        error_diff_array.append((calculate_difference(projecti,a) + calculate_difference(projectj,value)) / 2)
error_matrix = (np.array(error_diff_array).reshape(10, 10))  # resha
error_matrix
# Out:
# array([[2620505.47999695, 3723531.51257694, 2794255.97933497,
#         3306527.27725651, 2554878.29613897, 3399708.63401308,
#         2950279.94013483, 3394693.05715847, 2715760.79181432,
#         3794122.07523688],
#        [3723593.47414913, 3950781.70202352, 3699712.8510395 ,
#         4038931.38688638, 3450419.01197665, 4211427.66612607,
#         3685527.11116024, 4230699.40393758, 3489158.25303389,
#         4135173.61408111],
#        [2794597.50576277, 3699915.53205083, 2447705.57262465,
#         2939394.20052268, 2423584.79342669, 2967154.11847329,
#         2685750.26578141, 3200136.34522872, 2813573.76389461,
#         3634816.31073077],
#        [3306917.45210809, 4039198.73198212, 2939389.63392623,
#         3116500.9671259 , 2889748.21665282, 3262760.99786215,
#         3028710.08978302, 3546060.17047322, 3202965.93580174,
#         3896861.37611153],
#        [2554870.22387621, 3450425.80632112, 2423752.13357452,
#         2889652.28490036, 2180392.72057194, 2954875.48965347,
#         2553906.23406002, 3041231.38203146, 2543462.17025769,
#         3441364.14237953],
#        [3399299.57807023, 4211530.00424751, 2967090.12771878,
#         3262729.67359327, 2955004.39865911, 3231125.75405121,
#         3100444.9249713 , 3610813.4603449 , 3386767.21811115,
#         4075453.14104221],
#        [2950261.355649  , 3685132.15874418, 2685808.54936006,
#         3028676.84746943, 2553862.81484334, 3100613.08288564,
#         2630246.93898622, 3341612.13910299, 2874056.41510618,
#         3648295.57136173],
#        [3394775.08682151, 4230809.48899818, 3199731.21923164,
#         3545550.44328842, 3041360.74022376, 3610858.31202692,
#         3341284.90949363, 3441110.58858903, 3386113.09510467,
#         4139501.22037173],
#        [2715931.44957361, 3488977.15900812, 2813538.45782676,
#         3203134.62361022, 2543618.33751109, 3387147.88280901,
#         2873590.86698706, 3386104.35908325, 2440642.7605746 ,
#         3541597.4094233 ],
#        [3794771.2640152 , 4135367.90355316, 3634844.15391906,
#         3897538.99723615, 3441357.0765586 , 4075341.51367707,
#         3648334.75318408, 4139567.41434489, 3541676.58865747,
#         4021101.6035518 ]])

# %%
np.savetxt("partc_distances.csv", error_matrix, delimiter=",")

# %%
A = np.identity(10) - (np.ones(10).reshape((10,1)) @ (np.ones(10).reshape(1,10)))/10
W = (A@error_matrix@A.T) / -2
s,v = np.linalg.eig(W)
result = v[:,:2] @ np.diag(s[:2] ** 0.5)
plt.figure()
plt.scatter(result[:, 0], result[:, 1])
plt.axis('equal');
plt.xlabel("First component")
plt.ylabel("Second component")
plt.title("plot for dimension reduction with our special distance matrix")
plt.savefig("PartC.png")
plt.show()
plt.close()
