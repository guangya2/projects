# %% [raw]
# Author: Guangya Wan
# Time : Feb 21 2019

# %% [markdown]
# # Introduction

# %% [markdown]
# ### Axelord's tournament is hold back to 1970s; it's held by professor Axelord who wish to find the best way to deal with iterated prisioner's dilemma. Among more than 60 participants, it turns out that the Tit-for-tat designed by Anatol Rapoport is the winner, and it is also the simplest one

# %% [markdown]
# ### Tit-for-tat have lots of variations(though they did not win the original version in the tournaments), I will show the effects of the original tit-for-tat and one of its variations -- Grudger here.
# ### Tit for tat is to cooperate first, and do whatever its opponents do last time. Grudger is basically the same, except that it does not forgive. So as long as the opponent defects, it will always defect in the future rounds.

# %% [markdown]
# ### The top ranked stretegies in Axelord's tournaments have genereally 4 properties : Nice, Retaliatation, Forgiveness, and non-envious(Not trying to get higher than your opponents) However, this really depends on the enviroments of the tournaments, one can not simply give tit-for-tat and expected to win every single time. I will show some examples below

# %% [markdown]
# # Simulating matches

# %%
import axelrod as axl
import pprint

# %%
players = [axl.Cooperator(), axl.Defector(),
           axl.TitForTat(), axl.Grudger(),axl.Random(0.66)]
# grudge is similar to titfor tat expect it does not forgive
tournament = axl.Tournament(players,turns = 100, repetitions = 10)
results = tournament.play()
plot = axl.Plot(results)
p = plot.payoff()
p.show()
summary = results.summarise()
pprint.pprint(summary)
# Out:
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 52.53it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 124.88it/s]
# /home/wan/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# [Player(Rank=0, Name='Defector', Median_score=2.6950000000000003, Cooperation_rating=0.0, Wins=4.0, Initial_C_rate=0.0, CC_rate=0.0, CD_rate=0.0, DC_rate=0.42000000000000004, DD_rate=0.58, CC_to_C_rate=0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=1, Name='Grudger', Median_score=2.62, Cooperation_rating=0.50825, Wins=1.0, Initial_C_rate=1.0, CC_rate=0.50325, CD_rate=0.005, DC_rate=0.15525, DD_rate=0.3365, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=2, Name='Tit For Tat', Median_score=2.385, Cooperation_rating=0.6705, Wins=0.0, Initial_C_rate=1.0, CC_rate=0.61175, CD_rate=0.058750000000000004, DC_rate=0.055, DD_rate=0.2745, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=1.0, DD_to_C_rate=0),
#  Player(Rank=3, Name='Cooperator', Median_score=2.0025, Cooperation_rating=1.0, Wins=0.0, Initial_C_rate=1.0, CC_rate=0.667, CD_rate=0.333, DC_rate=0.0, DD_rate=0.0, CC_to_C_rate=1.0, CD_to_C_rate=1.0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=4, Name='Random: 0.66', Median_score=1.7575000000000003, Cooperation_rating=0.65725, Wins=1.5, Initial_C_rate=0.45, CC_rate=0.282, CD_rate=0.37525, DC_rate=0.14175000000000001, DD_rate=0.201, CC_to_C_rate=0.702361861570466, CD_to_C_rate=0.6611344077591738, DC_to_C_rate=0.614122880177926, DD_to_C_rate=0.6413772780569825)]

# %%
players = [axl.Defector(),axl.TitForTat(), 
           axl.Grudger(),axl.Random(0.1),axl.Random(0.9)]
# grudge is similar to titfor tat expect it does not forgive
tournament = axl.Tournament(players,turns = 100, repetitions = 10)
results = tournament.play()
summary = results.summarise()
plot = axl.Plot(results)
p = plot.payoff()
p.show()
summary = results.summarise()
pprint.pprint(summary)
# Out:
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 29.95it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 177.75it/s]
# [Player(Rank=0, Name='Grudger', Median_score=2.4675000000000002, Cooperation_rating=0.27725, Wins=2.0, Initial_C_rate=1.0, CC_rate=0.26975, CD_rate=0.0075, DC_rate=0.23475, DD_rate=0.488, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=1, Name='Tit For Tat', Median_score=2.04375, Cooperation_rating=0.5065, Wins=0.0, Initial_C_rate=1.0, CC_rate=0.45775, CD_rate=0.04875, DC_rate=0.0435, DD_rate=0.45, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=1.0, DD_to_C_rate=0),
#  Player(Rank=2, Name='Defector', Median_score=2.015, Cooperation_rating=0.0, Wins=4.0, Initial_C_rate=0.0, CC_rate=0.0, CD_rate=0.0, DC_rate=0.25425, DD_rate=0.74575, CC_to_C_rate=0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=3, Name='Random: 0.1', Median_score=1.8875, Cooperation_rating=0.10325, Wins=2.0, Initial_C_rate=0.125, CC_rate=0.025249999999999998, CD_rate=0.078, DC_rate=0.228, DD_rate=0.6687500000000001, CC_to_C_rate=0.08932584269662922, CD_to_C_rate=0.08322352740892067, DC_to_C_rate=0.14526590510418003, DD_to_C_rate=0.10477046267010069),
#  Player(Rank=4, Name='Random: 0.9', Median_score=0.9299999999999999, Cooperation_rating=0.90075, Wins=0.0, Initial_C_rate=0.925, CC_rate=0.24774999999999997, CD_rate=0.653, DC_rate=0.026749999999999996, DD_rate=0.07250000000000001, CC_to_C_rate=0.8996325561745205, CD_to_C_rate=0.907637397003354, DC_to_C_rate=0.9431372549019609, DD_to_C_rate=0.8502017130089374)]

# %%
players = [axl.Defector(),axl.TitForTat(), axl.Grudger()
           ,axl.Random(0.1),axl.Random(0.05)] 
# grudge is similar to titfor tat expect it does not forgive
tournament = axl.Tournament(players,turns = 100, repetitions = 10)
results = tournament.play()
summary = results.summarise()
plot = axl.Plot(results)
p = plot.payoff()
p.show()
summary = results.summarise()
pprint.pprint(summary)
# Out:
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 37.91it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 141.11it/s]
# [Player(Rank=0, Name='Grudger', Median_score=1.6375, Cooperation_rating=0.25775, Wins=2.0, Initial_C_rate=1.0, CC_rate=0.25025, CD_rate=0.0075, DC_rate=0.0345, DD_rate=0.70775, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=1, Name='Tit For Tat', Median_score=1.6087500000000001, Cooperation_rating=0.29475, Wins=0.0, Initial_C_rate=1.0, CC_rate=0.25299999999999995, CD_rate=0.041749999999999995, DC_rate=0.03475, DD_rate=0.6705000000000001, CC_to_C_rate=1.0, CD_to_C_rate=0, DC_to_C_rate=1.0, DD_to_C_rate=0),
#  Player(Rank=2, Name='Defector', Median_score=1.145, Cooperation_rating=0.0, Wins=4.0, Initial_C_rate=0.0, CC_rate=0.0, CD_rate=0.0, DC_rate=0.037000000000000005, DD_rate=0.963, CC_to_C_rate=0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=3, Name='Random: 0.05', Median_score=1.1075, Cooperation_rating=0.0475, Wins=2.0, Initial_C_rate=0.025, CC_rate=0.002, CD_rate=0.0455, DC_rate=0.036750000000000005, DD_rate=0.9157500000000001, CC_to_C_rate=0, CD_to_C_rate=0.04558954718838439, DC_to_C_rate=0.086144578313253, DD_to_C_rate=0.047814085271383346),
#  Player(Rank=4, Name='Random: 0.1', Median_score=1.0775000000000001, Cooperation_rating=0.0895, Wins=1.0, Initial_C_rate=0.1, CC_rate=0.00375, CD_rate=0.08575, DC_rate=0.0375, DD_rate=0.873, CC_to_C_rate=0, CD_to_C_rate=0.08885013062494264, DC_to_C_rate=0.11785714285714287, DD_to_C_rate=0.08966450664230455)]

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### There are no stretegies either mathmatical or emprically proved to win all the iterated games right now. It dependes on the ecology of the enviroments.In a tournaments where most of players perfer to be "nice", a defector can usually be ranked as 1st. In a game where most players like to defect, tit-for-tat or its variation are often the winner
# ### There are other better stretegies nowdays where in a game you can assign mutiple players. You can assign a predetermined winner and  sacrifice the rest of other players. Specifically, they are programmed to able to recoginize the winner. If it's winner, they will always cooperate, otherwise they will defect to lower their opponents' scores

# %% [markdown]
# # Discussion

# %% [markdown]
# ## I think the probability of decision of opponents(if they are random) can be described by binomal distirbution or bayes network(if they are dependent on last move), so very useful information(like we see in the summary above) can be retrieved after many rounds. It will be often meaningless at the beginning of the game since the sample is too small, however, after a reasonable amounts of games, Statistics can be powerful.
# ## So My stretegy is to play random for the first 30 rounds in order to find opponents' distribution and then using some probability and statistics techniques to maximize our scores to outperform tit-for-tat, what are your opinions?
